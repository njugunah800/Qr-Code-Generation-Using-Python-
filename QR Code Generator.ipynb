# %%
# !pip install qrcode[pil]
# Out:
# Requirement already satisfied: qrcode[pil] in c:\users\hp\anaconda3\lib\site-packages (8.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from qrcode[pil]) (0.4.6)
# Requirement already satisfied: pillow>=9.1.0 in c:\users\hp\anaconda3\lib\site-packages (from qrcode[pil]) (10.4.0)

# %%
import qrcode
from PIL import Image

data = input("Enter your link to generate QR: ")

qr = qrcode.QRCode(version=2, box_size=10, border=4)
qr.add_data(data)
qr.make(fit=True)

image = qr.make_image(fill="black", back_color="green")

image.save("qr_code.png")
Image.open("qr_code.png")
# Out:
# Enter your link to generate QR:  https://learn.emobilis-lms.org/
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=370x370>
